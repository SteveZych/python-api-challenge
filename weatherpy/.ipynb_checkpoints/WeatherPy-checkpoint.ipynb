# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 629

# %%
#  Perform API Calls
# Perform a weather check on each city using a series of successive API calls.
# Include a print log of each city as it'sbeing processed (with the city number and city name).
lat = []
lng = []
maxTemp = []
humidity = []
cloudiness = []
windSpeed = []
country = []
date = []

for city in cities:
    try:
        weatherURL = f"http://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}"
        response = requests.get(weatherURL).json()
        print(f"{city} {response['weather'][0]['id']}")
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        maxTemp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        windSpeed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
    except: 
        print(f"{city} not found.")
# Out:
# nizhniy tsasuchey 800
# kodiak 800
# punta arenas 802
# atuona 500
# jamestown 501
# mar del plata 800
# port hedland 804
# butaritari 804
# meadow lake 803
# pangnirtung 500
# albany 804
# zhanakorgan 802
# port elizabeth 801
# rikitea 500
# saint anthony 501
# clyde river 701
# ushuaia 802
# tasiilaq 801
# cherskiy 803
# ilulissat 601
# dzilam gonzalez 800
# prince rupert 800
# dikson 804
# qaanaaq 801
# bredasdorp 804
# bethel 804
# galle 804
# port blair 802
# bundaberg 800
# saint-philippe 500
# karratha 802
# taolanaro not found.
# thompson 804
# ahipara 802
# mataura 804
# east london 802
# mahon 801
# caconda 804
# hilo 800
# bukama 501
# kanpur 721
# saskylakh 804
# fairbanks 802
# forestville 803
# yar-sale 802
# ponta do sol 801
# the valley 801
# jieshi 800
# kamenka 804
# cape town 803
# kaitangata 804
# codrington 804
# russell 800
# surt 804
# saldanha 804
# korla 804
# vaini 801
# aklavik 804
# port alfred 803
# tulagi 804
# saebovik not found.
# olafsvik 802
# rawson 800
# namatanai 501
# yellowknife 800
# dukat 804
# mount isa 800
# alpoyeca 800
# sao jose da coroa grande 803
# adrar 800
# golovchino 804
# tuktoyaktuk 803
# puerto ayora 500
# teneguiban not found.
# celestun 800
# khatanga 804
# chodavaram 701
# los llanos de aridane 800
# hobart 804
# karuzi 500
# katsuura 803
# dunedin 804
# terrace 802
# lorengau 804
# ancud 500
# purwodadi 804
# kapaa 500
# sovetskiy 801
# lebu 800
# inuvik 804
# bluff 500
# barentsburg not found.
# pacific grove 803
# san patricio 803
# yeppoon 802
# alofi 500
# puerto leguizamo 804
# mehamn 802
# buchanan 800
# kieta 500
# arraial do cabo 800
# vaitupu not found.
# dinsor not found.
# grand river south east not found.
# avarua 801
# tsihombe not found.
# guerrero negro 800
# sentyabrskiy not found.
# quatre cocos 500
# belushya guba not found.
# areia branca 803
# christchurch 803
# porosozero 804
# kirakira 803
# narsaq 801
# mount gambier 804
# cap-haitien 804
# mangaratiba 800
# naze 804
# busselton 804
# le port 500
# chokurdakh 804
# illoqqortoormiut not found.
# ulagan 803
# lolua not found.
# ust-koksa 801
# barawe not found.
# nioro 800
# lenger 800
# biloela 800
# tornio 600
# bolshoy uluy not found.
# mitsamiouli 500
# yumen 804
# maragogi 804
# souillac 500
# new norfolk 804
# faya 800
# constitucion 800
# hamilton 804
# elko 800
# wakkanai 804
# kolokani 800
# louisbourg not found.
# maniitsoq 803
# bathsheba 762
# tautira 500
# bacolod 500
# pauini 804
# hasaki 803
# makakilo city 800
# kavieng 500
# bembereke 802
# morris 804
# buqayq not found.
# bahia blanca 800
# tateyama 501
# simbahan 800
# joshimath 804
# palabuhanratu not found.
# marsh harbour 803
# kedrovyy 601
# basco 802
# vredendal 803
# banda aceh 803
# tres rios 800
# palmer 804
# of not found.
# nouakchott 800
# kulhudhuffushi 801
# macomer 802
# hay river 801
# kampot 801
# la ronge 802
# hurghada 800
# mehriz 801
# lamu 800
# vangaindrano 500
# saleaula not found.
# arcata 721
# kawalu 804
# phalombe 804
# prieska 801
# noyabrsk 804
# zeya 800
# ukiah 800
# asfi 803
# belyy yar 804
# torbay 501
# northam 801
# nome 601
# boyolangu 800
# warqla not found.
# airai 804
# ranong 800
# sungaipenuh 804
# gubkinskiy 804
# beringovskiy 600
# bengkulu 500
# castrillon 800
# beauvais 803
# varberg 801
# pavlovsk 803
# canakkale 800
# severnyy 803
# nelson bay 804
# punta cardon 802
# tecoanapa 800
# puerto escondido 801
# sezana 804
# eureka 721
# kolondieba 802
# samalaeulu not found.
# jibuti 801
# ewo 802
# nantucket 804
# dulyapino 800
# tigil 804
# barrow 801
# ocean city 804
# guozhen 804
# touros 802
# leander 800
# havre-saint-pierre 800
# lompoc 800
# yenagoa 802
# antofagasta 802
# tabuk 804
# novikovo 804
# shimanovsk 801
# itarantim 800
# saulkrasti 800
# conde 802
# portree 800
# coquimbo 802
# olinda 803
# emerald 800
# timberlake 802
# bardiyah 800
# phan rang not found.
# port macquarie 800
# chakrata 800
# meghraj 800
# kyren 803
# macapa 802
# abalak 800
# flinders 800
# alta floresta 802
# klaksvik 803
# haines junction 802
# nuuk 802
# nizhneyansk not found.
# karkaralinsk not found.
# dudinka 804
# bilibino 803
# san cristobal 802
# kuppam 801
# ouesso 803
# sorland 803
# kamina 802
# esperance 803
# pyshchug 804
# blairmore 600
# aksarka 804
# estelle 802
# sakaraha 804
# linxia 803
# pangkalanbuun 804
# marovoay 500
# zamosc 800
# grindavik 802
# turukhansk 804
# tabiauea not found.
# sao joao da barra 802
# saint-pierre 501
# okhotsk 804
# brae 801
# fillan 500
# boa vista 500
# akividu 801
# luderitz 803
# maceio 803
# yurga 601
# zatoka 800
# ilo 800
# tiksi 804
# poya 804
# los banos 801
# atherton 800
# mackay 804
# buenos aires 800
# utiroa not found.
# townsville 800
# grand centre not found.
# camacari 802
# chegutu 800
# biak 804
# zverinogolovskoye 804
# leningradskiy 804
# dodola 804
# krasnoselkup 804
# yulara 804
# springfield 800
# college 804
# nanortalik 801
# entre rios 804
# lilongwe 802
# srednekolymsk 803
# san quintin 800
# mackenzie 800
# harper 802
# oxbow 600
# kudahuvadhoo 802
# morant bay 801
# neftcala 800
# kletskaya 804
# mana 500
# bagotville 802
# te anau 501
# aswan 800
# auki 803
# cap malheureux 501
# wad rawah 803
# lyuban 804
# caronport 600
# skibbereen 803
# foz 804
# bonavista 501
# san ramon de la nueva oran 800
# dzaoudzi 501
# gorontalo 500
# kachikau not found.
# belokurikha 804
# vostochnyy 800
# vila velha 801
# vallenar 800
# matagami 803
# khonuu not found.
# north myrtle beach 800
# lerwick 801
# karachi 721
# skagastrond not found.
# man 501
# luau 804
# suzu not found.
# novovasylivka 804
# valjala not found.
# bambous virieux 500
# temiscaming 804
# mamakan 804
# bobcaygeon 804
# anagni 500
# kodinsk 600
# rovaniemi 800
# dobrany 804
# obihiro 804
# kazalinsk not found.
# jiddah not found.
# springdale 800
# sambava 804
# yukhnov 804
# santa rosa 801
# benghazi 804
# banmo not found.
# royan 800
# grand-lahou 803
# bandrele 500
# grand gaube 500
# pijijiapan 800
# wilmington island 801
# hobbs 800
# ugoofaaru 804
# aspindza 804
# stoyba not found.
# rock sound 800
# emmett 800
# walvis bay 800
# pitimbu 802
# tuatapere 500
# black river 801
# thinadhoo 803
# shache 804
# djambala 802
# kruisfontein 801
# vanimo 501
# alyangula 802
# sibolga 802
# burnie 804
# voh 803
# suileng 803
# ust-barguzin 800
# west wendover 800
# wawa 803
# zaria 804
# viedma 800
# baruun-urt 803
# turmalina 804
# umarkot 801
# coihaique 801
# san carlos de bariloche 802
# north bend 800
# alice springs 804
# barra patuca 800
# belaya gora 804
# bairiki 803
# baiyin 800
# flin flon 601
# sendai 804
# yamada 804
# douglas 800
# santa vitoria do palmar 800
# vuktyl 804
# wanning 801
# gorin 601
# bumba 802
# kirando 500
# kyzyl-suu 801
# augusto correa 801
# jorochito 803
# visby 804
# tadine 501
# mocambique not found.
# balimo not found.
# lardos 800
# gilazi not found.
# laguna 800
# halalo not found.
# likasi 804
# el carmen 804
# ondjiva 802
# neryungri 804
# vila do maio 800
# iqaluit 804
# chino valley 800
# maghama not found.
# potosi 500
# nemuro 804
# hendijan not found.
# henties bay 800
# samusu not found.
# kirensk 803
# birao 804
# hammond 803
# alotau not found.
# teguldet 804
# khani 803
# murgab 804
# inhambane 802
# araguatins not found.
# manyana 800
# yelatma 804
# bakel 800
# kerema 804
# prado 803
# garmsar 801
# guanica 803

# %%
#  Convert Raw Data to DataFrame
# Export the city data into a .csv.
# Display the DataFrame

weather_df = {"Lat": lat,
             "Lng": lng,
             "Max Temp": maxTemp,
             "Humidity": humidity,
             "Cloudiness": cloudiness,
             "Wind Speed": windSpeed,
             "Country": country,
             "Date": date}
weather_df = pd.DataFrame(weather_df)
weather_df
# Out:
#          Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0    50.5167  115.1333    267.46        38           7        2.84      RU
# 1    57.7900 -152.4072    278.15        70           1        2.06      US
# 2   -53.1500  -70.9167    283.15        53          40       10.29      CL
# 3    -9.8000 -139.0333    300.22        75          38        7.70      PF
# 4    42.0970  -79.2353    285.37        87          90        4.12      US
# ..       ...       ...       ...       ...         ...         ...     ...
# 567  14.9050  -12.4568    311.63         9           3        2.23      SN
# 568  -7.9631  145.7785    297.09        86          88        1.52      PG
# 569 -17.3411  -39.2208    299.94        61          71        4.50      BR
# 570  35.2182   52.3409    295.35        19          12        1.74      IR
# 571  17.9716  -66.9080    303.15        55          68        2.24      PR
#
#            Date
# 0    1618253806
# 1    1618253583
# 2    1618253595
# 3    1618253154
# 4    1618253727
# ..          ...
# 567  1618253953
# 568  1618253953
# 569  1618253716
# 570  1618253954
# 571  1618253954
#
# [572 rows x 8 columns]

# %%
weather_df[weather_df['Humidity']>100]
# Out:
# Empty DataFrame
# Columns: [Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  572.000000  572.000000  572.000000  572.000000  572.000000  572.000000
# mean    20.562147   21.034010  288.009860   69.131119   55.019231    3.729545
# std     33.518999   91.658759   13.612801   23.448612   39.390425    2.459302
# min    -54.800000 -175.200000  240.080000    7.000000    0.000000    0.180000
# 25%     -8.293400  -61.073075  279.777500   54.750000   13.000000    1.965000
# 50%     25.084350   26.138650  290.440000   76.000000   64.000000    3.100000
# 75%     50.242450  102.324125  299.082500   88.000000   98.000000    5.140000
# max     78.218600  179.316700  311.630000  100.000000  100.000000   18.010000
#
#                Date
# count  5.720000e+02
# mean   1.618254e+09
# std    1.792070e+02
# min    1.618253e+09
# 25%    1.618254e+09
# 50%    1.618254e+09
# 75%    1.618254e+09
# max    1.618254e+09

# %%
#Temperature vs. Latitude
temp = weather_df['Max Temp']
lat = weather_df['Lat']
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
plt.title("Temperature (F) vs. Latitude")
plt.scatter(lat,temp)

# %%
# Humidity vs. Latitude
humidity = weather_df['Humidity']
plt.scatter(lat,humidity)

# %%
# Cloudiness vs. Latitude
cloudiness = weather_df['Cloudiness']
plt.scatter(lat, cloudiness)

# %%
# Wind speed vs. Latitude
windSpeed = weather_df["Wind Speed"]
plt.scatter(lat,windSpeed)

# %%
# Northern Hemisphere - Temperature (F) vs. Latitude
northHem = weather_df[weather_df['Lat']>= 0]
northHemLat = northHem['Lat']
northHemTemp = northHem['Max Temp']
plt.scatter(northHemLat,northHemTemp)

# %%
# Southern Hemisphere - Temperature (F) vs. Latitude
southHem = weather_df[weather_df['Lat']< 0]
southHemLat = southHem["Lat"]
southHemTemp = southHem["Max Temp"]
plt.scatter(southHemLat,southHemTemp)

# %%
# Northern Hemisphere - Humidity (%) vs. Latitude
northHemHum = northHem['Humidity']
plt.scatter(northHemLat,northHemHum)

# %%
# Southern Hemisphere - Humidity (%) vs. Latitude
southHemHum = southHem['Humidity']
plt.scatter(southHemLat,southHemHum)

# %%
# Northern Hemisphere - Cloudiness (%) vs. Latitude
northHemCloud = northHem["Cloudiness"]
plt.scatter(northHemLat,northHemCloud)

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude
southHemCloud = southHem["Cloudiness"]
plt.scatter(southHemLat,southHemCloud)

# %%
# Northern Hemisphere - Wind Speed (mph) vs. Latitude
northHemWind = northHem["Wind Speed"]
plt.scatter(northHemLat,northHemWind)

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude
southHemWind = southHem['Wind Speed']
plt.scatter(southHemLat,southHemWind)
